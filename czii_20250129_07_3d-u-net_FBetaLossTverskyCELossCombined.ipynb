# %% [markdown]
# # Install pkgs

# %% [markdown]
# **Note:** This is training notebook only. Inference ain't included in .
# Anybody who wants to use this notebook for inference purposes is most welcome.

# %%
import os
import shutil
import numpy as np
from pathlib import Path
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchinfo
import zarr, copick
from tqdm import tqdm
import napari
import mlflow
import mlflow.pytorch
from copick_utils.segmentation import segmentation_from_picks
import copick_utils.writers.write as write
from collections import defaultdict
import matplotlib.pyplot as plt
import pandas as pd
import gc

gc.enable()

# %%
torch._dynamo.config.cache_size_limit = 64

# %%
path = '/media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/'
output_path = path + 'output/'

# %%
# Make a copick project

config_blob = """{
    "name": "czii_cryoet_mlchallenge_2024",
    "description": "2024 CZII CryoET ML Challenge training data.",
    "version": "1.0.0",

    "pickable_objects": [
        {
            "name": "apo-ferritin",
            "is_particle": true,
            "pdb_id": "4V1W",
            "label": 1,
            "color": [  0, 117, 220, 128],
            "radius": 60,
            "map_threshold": 0.0418
        },
        {
            "name": "beta-galactosidase",
            "is_particle": true,
            "pdb_id": "6X1Q",
            "label": 2,
            "color": [ 76,   0,  92, 128],
            "radius": 90,
            "map_threshold": 0.0578
        },
        {
            "name": "ribosome",
            "is_particle": true,
            "pdb_id": "6EK0",
            "label": 3,
            "color": [  0,  92,  49, 128],
            "radius": 150,
            "map_threshold": 0.0374
        },
        {
            "name": "thyroglobulin",
            "is_particle": true,
            "pdb_id": "6SCJ",
            "label": 4,
            "color": [ 43, 206,  72, 128],
            "radius": 130,
            "map_threshold": 0.0278
        },
        {
            "name": "virus-like-particle",
            "is_particle": true,
            "label": 5,
            "color": [255, 204, 153, 128],
            "radius": 135,
            "map_threshold": 0.201
        }
    ],

    "overlay_root": "/media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay",

    "overlay_fs_args": {
        "auto_mkdir": true
    },

    "static_root": "/media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/static"
}"""

copick_config_path = path + "output/copick.config"
output_overlay = path + "output/overlay"

with open(copick_config_path, "w") as f:
    f.write(config_blob)
    
# Update the overlay
# Define source and destination directories
source_dir = path + 'train/overlay'
destination_dir = path + 'output/overlay'

# Walk through the source directory
for root, dirs, files in os.walk(source_dir):
    # Create corresponding subdirectories in the destination
    relative_path = os.path.relpath(root, source_dir)
    target_dir = os.path.join(destination_dir, relative_path)
    os.makedirs(target_dir, exist_ok=True)
    
    # Copy and rename each file
    for file in files:
        if file.startswith("curation_0_"):
            new_filename = file
        else:
            new_filename = f"curation_0_{file}"
            
        
        # Define full paths for the source and destination files
        source_file = os.path.join(root, file)
        destination_file = os.path.join(target_dir, new_filename)
        
        # Copy the file with the new name
        shutil.copy2(source_file, destination_file)
        print(f"Copied {source_file} to {destination_file}")
# Out:
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_5_4/Picks/apo-ferritin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_5_4/Picks/curation_0_apo-ferritin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_5_4/Picks/beta-amylase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_5_4/Picks/curation_0_beta-amylase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_5_4/Picks/beta-galactosidase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_5_4/Picks/curation_0_beta-galactosidase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_5_4/Picks/ribosome.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_5_4/Picks/curation_0_ribosome.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_5_4/Picks/thyroglobulin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_5_4/Picks/curation_0_thyroglobulin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_5_4/Picks/virus-like-particle.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_5_4/Picks/curation_0_virus-like-particle.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_69_2/Picks/apo-ferritin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_69_2/Picks/curation_0_apo-ferritin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_69_2/Picks/beta-amylase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_69_2/Picks/curation_0_beta-amylase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_69_2/Picks/beta-galactosidase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_69_2/Picks/curation_0_beta-galactosidase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_69_2/Picks/ribosome.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_69_2/Picks/curation_0_ribosome.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_69_2/Picks/thyroglobulin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_69_2/Picks/curation_0_thyroglobulin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_69_2/Picks/virus-like-particle.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_69_2/Picks/curation_0_virus-like-particle.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_4/Picks/apo-ferritin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_4/Picks/curation_0_apo-ferritin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_4/Picks/beta-amylase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_4/Picks/curation_0_beta-amylase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_4/Picks/beta-galactosidase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_4/Picks/curation_0_beta-galactosidase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_4/Picks/ribosome.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_4/Picks/curation_0_ribosome.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_4/Picks/thyroglobulin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_4/Picks/curation_0_thyroglobulin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_4/Picks/virus-like-particle.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_4/Picks/curation_0_virus-like-particle.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_6/Picks/apo-ferritin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_6/Picks/curation_0_apo-ferritin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_6/Picks/beta-amylase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_6/Picks/curation_0_beta-amylase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_6/Picks/beta-galactosidase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_6/Picks/curation_0_beta-galactosidase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_6/Picks/ribosome.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_6/Picks/curation_0_ribosome.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_6/Picks/thyroglobulin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_6/Picks/curation_0_thyroglobulin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_6_6/Picks/virus-like-particle.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_6_6/Picks/curation_0_virus-like-particle.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_73_6/Picks/apo-ferritin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_73_6/Picks/curation_0_apo-ferritin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_73_6/Picks/beta-amylase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_73_6/Picks/curation_0_beta-amylase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_73_6/Picks/beta-galactosidase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_73_6/Picks/curation_0_beta-galactosidase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_73_6/Picks/ribosome.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_73_6/Picks/curation_0_ribosome.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_73_6/Picks/thyroglobulin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_73_6/Picks/curation_0_thyroglobulin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_73_6/Picks/virus-like-particle.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_73_6/Picks/curation_0_virus-like-particle.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_86_3/Picks/apo-ferritin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_86_3/Picks/curation_0_apo-ferritin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_86_3/Picks/beta-amylase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_86_3/Picks/curation_0_beta-amylase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_86_3/Picks/beta-galactosidase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_86_3/Picks/curation_0_beta-galactosidase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_86_3/Picks/ribosome.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_86_3/Picks/curation_0_ribosome.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_86_3/Picks/thyroglobulin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_86_3/Picks/curation_0_thyroglobulin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_86_3/Picks/virus-like-particle.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_86_3/Picks/curation_0_virus-like-particle.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_99_9/Picks/apo-ferritin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_99_9/Picks/curation_0_apo-ferritin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_99_9/Picks/beta-amylase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_99_9/Picks/curation_0_beta-amylase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_99_9/Picks/beta-galactosidase.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_99_9/Picks/curation_0_beta-galactosidase.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_99_9/Picks/ribosome.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_99_9/Picks/curation_0_ribosome.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_99_9/Picks/thyroglobulin.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_99_9/Picks/curation_0_thyroglobulin.json
# Copied /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/train/overlay/ExperimentRuns/TS_99_9/Picks/virus-like-particle.json to /media/max1024/Extreme SSD1/Kaggle/czii-cryo-et-object-identification/output/overlay/ExperimentRuns/TS_99_9/Picks/curation_0_virus-like-particle.json

# %% [markdown]
# # Prepare the dataset
# ## 1. Get copick root

# %%
root = copick.from_file(copick_config_path)

copick_user_name = "copickUtils"
copick_segmentation_name = "paintedPicks"
voxel_size = 10
#tomo_type = "denoised"

# %% [markdown]
# ## 2. Generate multi-class segmentation masks from picks, and saved them to the copick overlay directory (one-time)

# %%
root
# Out:
# CopickRoot(user_id=None, len(pickable_objects)=None, len(runs)=None) at 0x786fe07f7380

# %%
# Just do this once
generate_masks = True

if generate_masks:
    target_objects = defaultdict(dict)
    for object in root.pickable_objects:
        if object.is_particle:
            target_objects[object.name]['label'] = object.label
            target_objects[object.name]['radius'] = object.radius


    for run in tqdm(root.runs):
        tomo = run.get_voxel_spacing(voxel_size)
        for tomogram in tomo.tomograms:
            tomo_type = tomogram.tomo_type
            image = tomogram.numpy()
            target = np.zeros(image.shape, dtype=np.uint8)
            for pickable_object in root.pickable_objects:
                pick = run.get_picks(object_name=pickable_object.name, user_id='curation')
                if len(pick):
                    target = segmentation_from_picks.from_picks(pick[0],
                                                                target,
                                                                target_objects[pickable_object.name]['radius'] * 0.5,
                                                                target_objects[pickable_object.name]['label']
                                                               )
            write.segmentation(run, target, copick_user_name, name=copick_segmentation_name)
# Out:
# 100%|█████████████████████████████████████████████| 7/7 [00:17<00:00,  2.45s/it]

# %% [markdown]
# ## 3. Get tomograms and their segmentaion masks (from picks) arrays

# %%
data_dicts = []
for run in tqdm(root.runs):
    tomo = run.get_voxel_spacing(voxel_size)#.get_tomograms(tomo_type)[0].numpy()
    for tomogram in tomo.tomograms:
        tomo_type = tomogram.tomo_type
        image = tomogram.numpy()
        segmentation = run.get_segmentations(name=copick_segmentation_name, user_id=copick_user_name, voxel_size=voxel_size, is_multilabel=True)[0].numpy()
        data_dicts.append({"tomo_type":tomo_type, "image": image, "label": segmentation})
    
print(np.unique(data_dicts[0]['label']))
# Out:
# 100%|█████████████████████████████████████████████| 7/7 [00:10<00:00,  1.56s/it]
# [0 1 2 3 4 5]

# %%
data_dicts[0].keys()
# Out:
# dict_keys(['tomo_type', 'image', 'label'])

# %%
data_dicts[0]['label'].shape
# Out:
# (184, 630, 630)

# %%
len(data_dicts)
# Out:
# 28

# %% [markdown]
# ## 4. Visualize the tomogram and painted segmentation from ground-truth picks

# %%
# Plot the images
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
plt.title('Tomogram')
plt.imshow(data_dicts[0]['image'][100],cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Painted Segmentation from Picks')
plt.imshow(data_dicts[0]['label'][100], cmap='viridis')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Simulated data prep

# %%
simulated_data_path = '../../czii_downloaded_data/simulated_training_data/'

# %%
simulated_experiments_list = [f for f in os.listdir(simulated_data_path) if 'TS_' in f]
simulated_experiments_list
# Out:
# ['TS_26',
#  'TS_13',
#  'TS_22',
#  'TS_17',
#  'TS_1',
#  'TS_24',
#  'TS_19',
#  'TS_4',
#  'TS_6',
#  'TS_23',
#  'TS_2',
#  'TS_16',
#  'TS_14',
#  'TS_20',
#  'TS_18',
#  'TS_0',
#  'TS_21',
#  'TS_3',
#  'TS_9',
#  'TS_7',
#  'TS_10',
#  'TS_11',
#  'TS_25',
#  'TS_12',
#  'TS_15',
#  'TS_5',
#  'TS_8']

# %%
particle_info = {
    "apo-ferritin": {"label": 1, "radius": 60},
    "beta-galactosidase": {"label": 2, "radius": 90},
    "ribosome": {"label": 3, "radius": 150},
    "thyroglobulin": {"label": 4, "radius": 130},
    "virus-like-particle": {"label": 5, "radius": 135}
}

# %%
def create_masks(image, locations_df):
    shape = image.shape
    volume = np.zeros(shape, dtype=np.uint8)

    for i in range(locations_df.shape[0]):
        center = (locations_df.loc[i, 'z'], locations_df.loc[i, 'y'], locations_df.loc[i, 'x'])
        radius = locations_df.loc[i, 'radius'] / 10 * 0.5
        intensity = locations_df.loc[i, 'label']

        z, y, x = np.ogrid[:shape[0], :shape[1], :shape[2]]
        
        mask = (x - center[2])**2 + (y - center[1])**2 + (z - center[0])**2 <= radius**2

        volume[mask] = intensity

    return volume

# %%
def append_simulation_data():
    for experiment in tqdm(simulated_experiments_list):
        
        tomogram = zarr.open(simulated_data_path + f'{experiment}/Reconstructions/VoxelSpacing10.000/Tomograms/100/{experiment}.zarr', mode='r')[0].__array__()
    
        location_dfs_list = []
        location_folders_list = os.listdir(f'{simulated_data_path}{experiment}/Reconstructions/VoxelSpacing10.000/Annotations/')
        for location_folder in location_folders_list:
            location_files_list = os.listdir(f'{simulated_data_path}{experiment}/Reconstructions/VoxelSpacing10.000/Annotations/{location_folder}/')
            for location_file in location_files_list:
                if 'orientedpoint.ndjson' in location_file:
                    if 'ferritin' in location_file:
                        label = particle_info['apo-ferritin']['label']
                        radius = particle_info['apo-ferritin']['radius']
    
                        location_df = pd.read_json(f'{simulated_data_path}{experiment}/Reconstructions/VoxelSpacing10.000/Annotations/{location_folder}/{location_file}', lines=True)
                        location_df['x'] = location_df['location'].apply(lambda x: x['x'])
                        location_df['y'] = location_df['location'].apply(lambda x: x['y'])
                        location_df['z'] = location_df['location'].apply(lambda x: x['z'])
                        location_df['label'] = label
                        location_df['radius'] = radius
    
                        location_dfs_list.append(location_df)
    
                    elif 'galacto' in location_file:
                        label = particle_info['beta-galactosidase']['label']
                        radius = particle_info['beta-galactosidase']['radius']
    
                        location_df = pd.read_json(f'{simulated_data_path}{experiment}/Reconstructions/VoxelSpacing10.000/Annotations/{location_folder}/{location_file}', lines=True)
                        location_df['x'] = location_df['location'].apply(lambda x: x['x'])
                        location_df['y'] = location_df['location'].apply(lambda x: x['y'])
                        location_df['z'] = location_df['location'].apply(lambda x: x['z'])
                        location_df['label'] = label
                        location_df['radius'] = radius
    
                        location_dfs_list.append(location_df)
    
                    elif 'ribosome' in location_file:
                        label = particle_info['ribosome']['label']
                        radius = particle_info['ribosome']['radius']
    
                        location_df = pd.read_json(f'{simulated_data_path}{experiment}/Reconstructions/VoxelSpacing10.000/Annotations/{location_folder}/{location_file}', lines=True)
                        location_df['x'] = location_df['location'].apply(lambda x: x['x'])
                        location_df['y'] = location_df['location'].apply(lambda x: x['y'])
                        location_df['z'] = location_df['location'].apply(lambda x: x['z'])
                        location_df['label'] = label
                        location_df['radius'] = radius
    
                        location_dfs_list.append(location_df)
    
                    elif 'thyro' in location_file:
                        label = particle_info['thyroglobulin']['label']
                        radius = particle_info['thyroglobulin']['radius']
    
                        location_df = pd.read_json(f'{simulated_data_path}{experiment}/Reconstructions/VoxelSpacing10.000/Annotations/{location_folder}/{location_file}', lines=True)
                        location_df['x'] = location_df['location'].apply(lambda x: x['x'])
                        location_df['y'] = location_df['location'].apply(lambda x: x['y'])
                        location_df['z'] = location_df['location'].apply(lambda x: x['z'])
                        location_df['label'] = label
                        location_df['radius'] = radius
    
                        location_dfs_list.append(location_df)
    
                    elif 'vlp' in location_file:
                        label = particle_info['virus-like-particle']['label']
                        radius = particle_info['virus-like-particle']['radius']
    
                        location_df = pd.read_json(f'{simulated_data_path}{experiment}/Reconstructions/VoxelSpacing10.000/Annotations/{location_folder}/{location_file}', lines=True)
                        location_df['x'] = location_df['location'].apply(lambda x: x['x'])
                        location_df['y'] = location_df['location'].apply(lambda x: x['y'])
                        location_df['z'] = location_df['location'].apply(lambda x: x['z'])
                        location_df['label'] = label
                        location_df['radius'] = radius
    
                        location_dfs_list.append(location_df)
    
                        
        all_particle_locations_df = pd.concat(location_dfs_list, ignore_index=True)
    
        mask_image = create_masks(tomogram, all_particle_locations_df)
    
        data_dicts.append({"tomo_type":'Unknown', "image": tomogram, "label": mask_image})

# %%
append_simulation_data()
# Out:
# 100%|███████████████████████████████████████████| 27/27 [22:16<00:00, 49.50s/it]

# %%
len(data_dicts)
# Out:
# 55

# %% [markdown]
# ## 5. Prepare dataloaders

# %%
from monai.data import DataLoader, Dataset, CacheDataset, decollate_batch
from monai.transforms import (
    Compose,
    EnsureChannelFirstd, 
    Orientationd,  
    AsDiscrete,  
    RandFlipd, 
    RandRotate90d, 
    NormalizeIntensityd,
    RandCropByLabelClassesd,
)
from monai.networks.nets import UNet
from monai.losses import DiceLoss, FocalLoss, TverskyLoss
from monai.metrics import DiceMetric, ConfusionMatrixMetric

# %%
my_num_samples = 16
train_batch_size = 1
val_batch_size = 1

# %%
import random

numbers = list(range(len(data_dicts)))
random_numbers = random.sample(numbers, int(len(data_dicts)/5))

print(random_numbers)
# Out:
# [14, 22, 50, 39, 0, 19, 25, 47, 54, 26, 27]

# %%
val_files = []
train_files = []
for i in range(len(data_dicts)):
    if i in random_numbers:
        val_files.append(data_dicts[i])
    else:
        train_files.append(data_dicts[i])

# %%
print(f"Number of training samples: {len(train_files)}")
print(f"Number of validation samples: {len(val_files)}")
# Out:
# Number of training samples: 44
# Number of validation samples: 11

# %%
num_classes = 6 # number of particles (5) + background (1)

# %%
# Non-random transforms to be cached
non_random_transforms = Compose([
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    NormalizeIntensityd(keys="image"),
    Orientationd(keys=["image", "label"], axcodes="RAS")
])

# Random transforms to be applied during training
random_transforms = Compose([
    RandCropByLabelClassesd(
        keys=["image", "label"],
        label_key="label",
        spatial_size=[96, 96, 96],
        num_classes=num_classes,
        num_samples=my_num_samples,
        allow_missing_keys=True
    ),
    RandRotate90d(keys=["image", "label"], prob=0.5, spatial_axes=[0, 2]),
    RandFlipd(keys=["image", "label"], prob=0.5, spatial_axis=0),    
])

# Create the cached dataset with non-random transforms
train_ds = CacheDataset(data=train_files, transform=non_random_transforms, cache_rate=1.0)

# Wrap the cached dataset to apply random transforms during iteration
train_ds = Dataset(data=train_ds, transform=random_transforms)

# DataLoader remains the same
train_loader = DataLoader(
    train_ds,
    batch_size=train_batch_size,
    shuffle=True,
    num_workers=4,
    pin_memory=torch.cuda.is_available()
)

# Validation transforms
val_transforms = Compose([
    EnsureChannelFirstd(keys=["image", "label"], channel_dim="no_channel"),
    NormalizeIntensityd(keys="image"),
    RandCropByLabelClassesd(
        keys=["image", "label"],
        label_key="label",
        spatial_size=[96, 96, 96],
        num_classes=num_classes,
        num_samples=my_num_samples,  # Use 1 to get a single, consistent crop per image
        allow_missing_keys=True
    ),
])

# Create validation dataset
val_ds = CacheDataset(data=val_files, transform=non_random_transforms, cache_rate=1.0)

# Wrap the cached dataset to apply random transforms during iteration
val_ds = Dataset(data=val_ds, transform=random_transforms)

# Create validation DataLoader
val_loader = DataLoader(
    val_ds,
    batch_size=val_batch_size,
    num_workers=4,
    pin_memory=torch.cuda.is_available(),
    shuffle=False,  # Ensure the data order remains consistent
)
# Out:
# Loading dataset: 100%|██████████████████████████| 44/44 [00:16<00:00,  2.62it/s]
# Loading dataset: 100%|██████████████████████████| 11/11 [00:04<00:00,  2.65it/s]

# %% [markdown]
# ## Model setup

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Create UNet, DiceLoss and Adam optimizer
model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=num_classes,
    channels=(48, 64, 80, 80),
    strides=(2, 2, 1),
    num_res_units=1,
).to(device)

lr = 1e-3
optimizer = torch.optim.Adam(model.parameters(), lr)
#loss_function = DiceLoss(include_background=True, to_onehot_y=True, softmax=True)  # softmax=True for multiclass
#loss_function = TverskyLoss(include_background=False, to_onehot_y=True, softmax=True, alpha=16/17, beta=1/17)  # softmax=True for multiclass
dice_metric = DiceMetric(include_background=False, reduction="mean", ignore_empty=True)  # must use onehot for multiclass
recall_metric = ConfusionMatrixMetric(include_background=False, metric_name="recall", reduction="None")
# Out:
# cuda

# %%
class FBetaLoss(nn.Module):
    def __init__(self, beta=4, eps=1e-6, class_weights=None, enzyme_classes=5):
        super().__init__()
        self.beta = beta
        self.eps = eps
        self.enzyme_classes = enzyme_classes
        
        self.class_weights = class_weights or {
            'apo-ferritin': 1,
            'beta-galactosidase': 2,
            'ribosome': 1,
            'thyroglobulin': 2,
            'virus-like-particle': 1,
        }
        self.weight_tensor = torch.tensor(
            [self.class_weights[k] for k in self.class_weights.keys()],
            dtype=torch.float32
        )

    def forward(self, y_pred, y_true):
        # Convert y_true to proper format
        y_true = y_true.squeeze(1).long()  # Remove channel dim & ensure integer type
        
        y_pred_probs = F.softmax(y_pred, dim=1)
        y_pred_enzymes = y_pred_probs[:, 1:self.enzyme_classes+1, ...]
        
        # One-hot encoding with proper type handling
        y_true_onehot = F.one_hot(y_true, num_classes=6).permute(0, 4, 1, 2, 3).float()
        y_true_enzymes = y_true_onehot[:, 1:self.enzyme_classes+1, ...]

        tp = (y_pred_enzymes * y_true_enzymes).sum(dim=(2, 3, 4))
        fp = (y_pred_enzymes * (1 - y_true_enzymes)).sum(dim=(2, 3, 4))
        fn = ((1 - y_pred_enzymes) * y_true_enzymes).sum(dim=(2, 3, 4))

        precision = tp / (tp + fp + self.eps)
        recall = tp / (tp + fn + self.eps)
        beta2 = self.beta ** 2
        f_beta = (1 + beta2) * (precision * recall) / (beta2 * precision + recall + self.eps)

        weight_tensor = self.weight_tensor.to(y_pred.device)
        weighted_f_beta = f_beta * weight_tensor
        aggregate_f_beta = weighted_f_beta.sum(dim=1) / weight_tensor.sum()
        
        return 1 - aggregate_f_beta.mean()

# %%
fbeta_loss_function = FBetaLoss()

# %%
class ParticleTverskyCrossEntropyLoss(nn.Module):
    def __init__(self, particle_weights, alpha=16/17, beta=1/17, ce_weight=1.0, tversky_weight=1.0, smooth=1e-6):
        """
        Args:
            particle_weights (torch.Tensor): Weights for 5 particles + background [0.0, 1.0, 2.0, 1.0, 2.0, 1.0]
            alpha: Tversky FP weight (prioritizes recall for beta=4)
            beta: Tversky FN weight
        """
        super().__init__()
        self.ce_weight = ce_weight
        self.tversky_weight = tversky_weight
        self.smooth = smooth
        self.alpha = alpha
        self.beta = beta
        
        # Cross-Entropy with particle weights (background weight=0)
        self.ce = nn.CrossEntropyLoss(weight=particle_weights)
        self.register_buffer('class_weights', particle_weights)  # [6] tensor

    def forward(self, inputs, targets):
        # Ensure targets have the correct shape and dtype
        ce_loss = self.ce(inputs, targets.squeeze(1).long())
    
        # Tversky Loss (3D-compatible)
        num_classes = inputs.shape[1]
        probs = F.softmax(inputs, dim=1)
        targets_onehot = F.one_hot(targets.squeeze(1).long(), num_classes).permute(0, 4, 1, 2, 3).float()  # BCDHW
    
        # Flatten spatial dimensions (3D)
        probs_flat = probs.view(probs.size(0), num_classes, -1)  # [B,6,D*H*W]
        targets_flat = targets_onehot.view(targets_onehot.size(0), num_classes, -1)
    
        # Calculate TP/FP/FN (broadcasted across classes)
        tp = (probs_flat * targets_flat).sum(dim=2)  # [B,6]
        fp = (probs_flat * (1 - targets_flat)).sum(dim=2)
        fn = ((1 - probs_flat) * targets_flat).sum(dim=2)
    
        # Tversky index per class
        tversky = (tp + self.smooth) / (tp + self.alpha*fp + self.beta*fn + self.smooth)  # [B,6]
        tversky_loss = 1 - tversky
    
        # Apply class weights
        weighted_tversky = tversky_loss * self.class_weights  # [B,6]
        tversky_loss = weighted_tversky.mean()
    
        # Combined loss
        return self.ce_weight * ce_loss + self.tversky_weight * tversky_loss

# %%
# Class order: [background, apo-ferritin, beta-galactosidase, ribosome, thyroglobulin, virus-like-particle]
particle_weights = torch.tensor([
    0.0,  # Background (weight=0)
    1.0,  # apo-ferritin
    2.0,  # beta-galactosidase (higher weight)
    1.0,  # ribosome
    2.0,  # thyroglobulin (higher weight)
    1.0   # virus-like-particle
], device='cuda')

tversky_ce_loss_function = ParticleTverskyCrossEntropyLoss(
    particle_weights=particle_weights,
    ce_weight=1.0,  # Balance with Tversky
    tversky_weight=1.0  # Emphasize recall
)

# %%
post_pred = AsDiscrete(argmax=True, to_onehot=num_classes)
post_label = AsDiscrete(to_onehot=num_classes)

# %%
def train(train_loader, model, metrics_function, optimizer, max_epochs=25):
    val_interval = 1
    best_metric = -1
    best_metric_epoch = -1
    epoch_loss_values = []
    metric_values = []

    model.to('cuda')
    model = torch.compile(model)

    torch.set_float32_matmul_precision('high')
    
    scaler = torch.amp.GradScaler('cuda')
    autocast_dtype = torch.float16    
    
    for epoch in range(max_epochs):
        print("-" * 10)
        print(f"epoch {epoch + 1}/{max_epochs}")
        model.train()
        epoch_loss = 0
        step = 0
        for batch_data in train_loader:
            step += 1
            inputs = batch_data["image"].to(device)
            labels = batch_data["label"].to(device)
            optimizer.zero_grad()

            with torch.autocast(device_type='cuda', dtype=autocast_dtype):
                outputs = model(inputs)
                fbeta_loss = fbeta_loss_function(outputs, labels)
                tversky_ce_loss = tversky_ce_loss_function(outputs, labels)
                total_loss = fbeta_loss * 0.7 + tversky_ce_loss * 0.3

            scaler.scale(total_loss).backward()  
            scaler.step(optimizer)  
            scaler.update() 
            
            epoch_loss += total_loss.item()
            #print(f"batch {step}/{len(train_ds) // train_loader.batch_size}, " f"train_loss: {loss.item():.4f}")
            
        epoch_loss /= step
        epoch_loss_values.append(epoch_loss)
        print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")
        mlflow.log_metric("train_loss", epoch_loss, step=epoch+1)

        if (epoch + 1) % val_interval == 0:
            model.eval()
            with torch.no_grad():
                for val_data in val_loader:
                    val_inputs = val_data["image"].to(device)
                    val_labels = val_data["label"].to(device)

                    with torch.autocast(device_type='cuda', dtype=autocast_dtype):
                        val_outputs = model(val_inputs)
                        metric_val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                        metric_val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                        
                        
                        # compute metric for current iteration
                        metrics_function(y_pred=metric_val_outputs, y=metric_val_labels)

                metrics = metrics_function.aggregate(reduction="mean_batch")
                metric_per_class = ["{:.4g}".format(x) for x in metrics]
                metric = torch.mean(metrics).numpy(force=True)
                mlflow.log_metric("validation metric", metric, step=epoch+1)
                for i,m in enumerate(metrics):
                    mlflow.log_metric(f"validation metric class {i+1}", m, step=epoch+1)
                metrics_function.reset()

                metric_values.append(metric)
                if metric > best_metric:
                    best_metric = metric
                    best_metric_epoch = epoch + 1
                    torch.save(model.state_dict(), os.path.join('./', f"3DUNet_Combined_Loss_Best_Metric_Model_{best_metric:.4f}.pth"))
                    
                    print("saved new best metric model")
                print(
                    f"current epoch: {epoch + 1} current mean recall per class: {', '.join(metric_per_class)}"
                    f"\ncurrent mean recall: {metric:.4f} "
                    f"\nbest mean recall: {best_metric:.4f} "
                    f"at epoch: {best_metric_epoch}"
                )

# %% [markdown]
# ## Training and tracking

# %%
from torchinfo import summary

mlflow.end_run()
mlflow.set_experiment('training 3D U-Net model for the cryoET ML Challenge')
epochs = 10000
with mlflow.start_run():
    params = {
        "epochs": epochs,
        "learning_rate": lr,
        "FBetaLoss": fbeta_loss_function.__class__.__name__,
        "TverskyCELoss": tversky_ce_loss_function.__class__.__name__,
        "metric_function": recall_metric.__class__.__name__,
        "optimizer": "Adam",
    }
    # Log training parameters.
    mlflow.log_params(params)

    # Log model summary.
    with open("model_summary.txt", "w") as f:
        f.write(str(summary(model)))
    mlflow.log_artifact("model_summary.txt")

    train(train_loader, model, dice_metric, optimizer, max_epochs=epochs)

    # Save the trained model to MLflow.
    mlflow.pytorch.log_model(model, "model")
# Out:
# ----------
# epoch 1/10000
# epoch 1 average loss: 1.4289
# saved new best metric model
# current epoch: 1 current mean recall per class: 0.0002679, 0.0005566, 0.07353, 0.004014, 0.01964
# current mean recall: 0.0196
# best mean recall: 0.0196 at epoch: 1
# ----------
# epoch 2/10000
# epoch 2 average loss: 1.2979
# saved new best metric model
# current epoch: 2 current mean recall per class: 0.0002567, 0.000333, 0.1221, 0.00343, 0.02537
# current mean recall: 0.0303
# best mean recall: 0.0303 at epoch: 2
# ----------
# epoch 3/10000
# epoch 3 average loss: 1.2282
# current epoch: 3 current mean recall per class: 0.0001797, 0.0004283, 0.118, 0.005377, 0.0229
# current mean recall: 0.0294
# best mean recall: 0.0303 at epoch: 2
# ----------
# epoch 4/10000
# epoch 4 average loss: 1.2333
# current epoch: 4 current mean recall per class: 0.0005412, 0.002641, 0.1104, 0.006413, 0.02505
# current mean recall: 0.0290
# best mean recall: 0.0303 at epoch: 2
# ----------
# epoch 5/10000
# epoch 5 average loss: 1.1904
# saved new best metric model
# current epoch: 5 current mean recall per class: 0.001956, 0.005069, 0.1474, 0.008587, 0.03058
# current mean recall: 0.0387
# best mean recall: 0.0387 at epoch: 5
# ----------
# epoch 6/10000
# epoch 6 average loss: 1.1656
# current epoch: 6 current mean recall per class: 0.00255, 0.007016, 0.1306, 0.009482, 0.04032
# current mean recall: 0.0380
# best mean recall: 0.0387 at epoch: 5
# ----------
# epoch 7/10000
# epoch 7 average loss: 1.1498
# saved new best metric model
# current epoch: 7 current mean recall per class: 0.002456, 0.0005092, 0.1354, 0.00954, 0.0523
# current mean recall: 0.0400
# best mean recall: 0.0400 at epoch: 7
# ----------
# epoch 8/10000
# epoch 8 average loss: 1.1397
# saved new best metric model
# current epoch: 8 current mean recall per class: 0.005166, 0.05897, 0.1927, 0.01106, 0.09472
# current mean recall: 0.0725
# best mean recall: 0.0725 at epoch: 8
# ----------
# epoch 9/10000
# epoch 9 average loss: 1.1204
# current epoch: 9 current mean recall per class: 0.007111, 0.08191, 0.1498, 0.01546, 0.09925
# current mean recall: 0.0707
# best mean recall: 0.0725 at epoch: 8
# ----------
# epoch 10/10000
# epoch 10 average loss: 1.1250
# saved new best metric model
# current epoch: 10 current mean recall per class: 0.02202, 0.1175, 0.1428, 0.03049, 0.1126
# current mean recall: 0.0851
# best mean recall: 0.0851 at epoch: 10
# ----------
# epoch 11/10000
# epoch 11 average loss: 1.1012
# saved new best metric model
# current epoch: 11 current mean recall per class: 0.04136, 0.1024, 0.1888, 0.04067, 0.2712
# current mean recall: 0.1289
# best mean recall: 0.1289 at epoch: 11
# ----------
# epoch 12/10000
# epoch 12 average loss: 1.0673
# saved new best metric model
# current epoch: 12 current mean recall per class: 0.08298, 0.1307, 0.1833, 0.05615, 0.2069
# current mean recall: 0.1320
# best mean recall: 0.1320 at epoch: 12
# ----------
# epoch 13/10000
# epoch 13 average loss: 1.0516
# current epoch: 13 current mean recall per class: 0.1258, 0.01335, 0.1907, 0.06059, 0.2048
# current mean recall: 0.1190
# best mean recall: 0.1320 at epoch: 12
# ----------
# epoch 14/10000
# epoch 14 average loss: 1.0676
# saved new best metric model
# current epoch: 14 current mean recall per class: 0.1468, 0.1447, 0.2084, 0.06341, 0.2646
# current mean recall: 0.1656
# best mean recall: 0.1656 at epoch: 14
# ----------
# epoch 15/10000
# epoch 15 average loss: 1.0262
# saved new best metric model
# current epoch: 15 current mean recall per class: 0.1261, 0.1073, 0.2409, 0.07375, 0.3044
# current mean recall: 0.1705
# best mean recall: 0.1705 at epoch: 15
# ----------
# epoch 16/10000
# epoch 16 average loss: 1.0215
# saved new best metric model
# current epoch: 16 current mean recall per class: 0.14, 0.1494, 0.1828, 0.06345, 0.4
# current mean recall: 0.1871
# best mean recall: 0.1871 at epoch: 16
# ----------
# epoch 17/10000
# epoch 17 average loss: 1.0381
# current epoch: 17 current mean recall per class: 0.1974, 0.1333, 0.2133, 0.06736, 0.2777
# current mean recall: 0.1778
# best mean recall: 0.1871 at epoch: 16
# ----------
# epoch 18/10000
# epoch 18 average loss: 1.0134
# saved new best metric model
# current epoch: 18 current mean recall per class: 0.1482, 0.1934, 0.276, 0.104, 0.2986
# current mean recall: 0.2040
# best mean recall: 0.2040 at epoch: 18
# ----------
# epoch 19/10000
# epoch 19 average loss: 0.9786
# saved new best metric model
# current epoch: 19 current mean recall per class: 0.3598, 0.1798, 0.292, 0.1383, 0.4596
# current mean recall: 0.2859
# best mean recall: 0.2859 at epoch: 19
# ----------
# epoch 20/10000
# epoch 20 average loss: 0.9843
# current epoch: 20 current mean recall per class: 0.253, 0.2161, 0.3087, 0.1343, 0.2719
# current mean recall: 0.2368
# best mean recall: 0.2859 at epoch: 19
# ----------
# epoch 21/10000
# epoch 21 average loss: 0.9563
# current epoch: 21 current mean recall per class: 0.2783, 0.1852, 0.2468, 0.1277, 0.5592
# current mean recall: 0.2794
# best mean recall: 0.2859 at epoch: 19
# ----------
# epoch 22/10000
# epoch 22 average loss: 0.9769
# current epoch: 22 current mean recall per class: 0.2738, 0.179, 0.2254, 0.1159, 0.3679
# current mean recall: 0.2324
# best mean recall: 0.2859 at epoch: 19
# ----------
# epoch 23/10000
# epoch 23 average loss: 0.9523
# current epoch: 23 current mean recall per class: 0.2909, 0.1068, 0.2226, 0.1119, 0.4819
# current mean recall: 0.2428
# best mean recall: 0.2859 at epoch: 19
# ----------
# epoch 24/10000
# epoch 24 average loss: 0.9474
# current epoch: 24 current mean recall per class: 0.2989, 0.2022, 0.2611, 0.1323, 0.3973
# current mean recall: 0.2583
# best mean recall: 0.2859 at epoch: 19
# ----------
# epoch 25/10000
# epoch 25 average loss: 0.9361
# current epoch: 25 current mean recall per class: 0.3188, 0.1702, 0.2298, 0.1379, 0.4144
# current mean recall: 0.2542
# best mean recall: 0.2859 at epoch: 19
# ----------
# epoch 26/10000
# epoch 26 average loss: 0.9289
# current epoch: 26 current mean recall per class: 0.3091, 0.2561, 0.2637, 0.1836, 0.4166
# current mean recall: 0.2858
# best mean recall: 0.2859 at epoch: 19
# ----------
# epoch 27/10000
# epoch 27 average loss: 0.9242
# current epoch: 27 current mean recall per class: 0.3294, 0.227, 0.2687, 0.1336, 0.3905
# current mean recall: 0.2698
# best mean recall: 0.2859 at epoch: 19
# ----------
# epoch 28/10000
# epoch 28 average loss: 0.9224
# saved new best metric model
# current epoch: 28 current mean recall per class: 0.3935, 0.2068, 0.2416, 0.15, 0.534
# current mean recall: 0.3052
# best mean recall: 0.3052 at epoch: 28
# ----------
# epoch 29/10000
# epoch 29 average loss: 0.9107
# current epoch: 29 current mean recall per class: 0.3183, 0.196, 0.2574, 0.1589, 0.5056
# current mean recall: 0.2872
# best mean recall: 0.3052 at epoch: 28
# ----------
# epoch 30/10000
# epoch 30 average loss: 0.9428
# saved new best metric model
# current epoch: 30 current mean recall per class: 0.3467, 0.2173, 0.2642, 0.1982, 0.5153
# current mean recall: 0.3083
# best mean recall: 0.3083 at epoch: 30
# ----------
# epoch 31/10000
# epoch 31 average loss: 0.9101
# saved new best metric model
# current epoch: 31 current mean recall per class: 0.3548, 0.2039, 0.3479, 0.1987, 0.6069
# current mean recall: 0.3424
# best mean recall: 0.3424 at epoch: 31
# ----------
# epoch 32/10000
# epoch 32 average loss: 0.9072
# current epoch: 32 current mean recall per class: 0.3098, 0.2665, 0.318, 0.1906, 0.4502
# current mean recall: 0.3070
# best mean recall: 0.3424 at epoch: 31
# ----------
# epoch 33/10000
# epoch 33 average loss: 0.9044
# saved new best metric model
# current epoch: 33 current mean recall per class: 0.3778, 0.3011, 0.2858, 0.2315, 0.525
# current mean recall: 0.3442
# best mean recall: 0.3442 at epoch: 33
# ----------
# epoch 34/10000
# epoch 34 average loss: 0.9047
# current epoch: 34 current mean recall per class: 0.3096, 0.1927, 0.2927, 0.1946, 0.56
# current mean recall: 0.3099
# best mean recall: 0.3442 at epoch: 33
# ----------
# epoch 35/10000
# epoch 35 average loss: 0.9032
# current epoch: 35 current mean recall per class: 0.37, 0.2425, 0.2525, 0.1457, 0.5642
# current mean recall: 0.3150
# best mean recall: 0.3442 at epoch: 33
# ----------
# epoch 36/10000
# epoch 36 average loss: 0.9396
# current epoch: 36 current mean recall per class: 0.4188, 0.2082, 0.3505, 0.1224, 0.5206
# current mean recall: 0.3241
# best mean recall: 0.3442 at epoch: 33
# ----------
# epoch 37/10000
# epoch 37 average loss: 0.8972
# current epoch: 37 current mean recall per class: 0.3726, 0.2416, 0.3062, 0.18, 0.5711
# current mean recall: 0.3343
# best mean recall: 0.3442 at epoch: 33
# ----------
# epoch 38/10000
# epoch 38 average loss: 0.8988
# current epoch: 38 current mean recall per class: 0.3067, 0.2242, 0.261, 0.1603, 0.4275
# current mean recall: 0.2759
# best mean recall: 0.3442 at epoch: 33
# ----------
# epoch 39/10000
# epoch 39 average loss: 0.8925
# current epoch: 39 current mean recall per class: 0.3422, 0.2483, 0.2921, 0.1488, 0.4662
# current mean recall: 0.2995
# best mean recall: 0.3442 at epoch: 33
# ----------
# epoch 40/10000
# epoch 40 average loss: 0.8841
# current epoch: 40 current mean recall per class: 0.3267, 0.2324, 0.3348, 0.1889, 0.5884
# current mean recall: 0.3342
# best mean recall: 0.3442 at epoch: 33
# ----------
# epoch 41/10000
# epoch 41 average loss: 0.8960
# saved new best metric model
# current epoch: 41 current mean recall per class: 0.3504, 0.266, 0.3942, 0.2476, 0.584
# current mean recall: 0.3684
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 42/10000
# epoch 42 average loss: 0.8779
# current epoch: 42 current mean recall per class: 0.297, 0.2281, 0.2705, 0.2135, 0.4811
# current mean recall: 0.2980
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 43/10000
# epoch 43 average loss: 0.8740
# current epoch: 43 current mean recall per class: 0.3726, 0.2165, 0.3353, 0.1888, 0.5182
# current mean recall: 0.3263
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 44/10000
# epoch 44 average loss: 0.8687
# current epoch: 44 current mean recall per class: 0.3433, 0.2772, 0.2969, 0.211, 0.5983
# current mean recall: 0.3454
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 45/10000
# epoch 45 average loss: 0.8759
# current epoch: 45 current mean recall per class: 0.4005, 0.2351, 0.4014, 0.2051, 0.5565
# current mean recall: 0.3597
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 46/10000
# epoch 46 average loss: 0.8699
# current epoch: 46 current mean recall per class: 0.3539, 0.3343, 0.2729, 0.2035, 0.5555
# current mean recall: 0.3440
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 47/10000
# epoch 47 average loss: 0.8873
# current epoch: 47 current mean recall per class: 0.2852, 0.183, 0.2906, 0.1756, 0.4442
# current mean recall: 0.2757
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 48/10000
# epoch 48 average loss: 0.8771
# current epoch: 48 current mean recall per class: 0.3535, 0.2186, 0.2388, 0.1845, 0.4741
# current mean recall: 0.2939
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 49/10000
# epoch 49 average loss: 0.8511
# current epoch: 49 current mean recall per class: 0.3905, 0.2134, 0.3943, 0.1944, 0.6402
# current mean recall: 0.3666
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 50/10000
# epoch 50 average loss: 0.8543
# current epoch: 50 current mean recall per class: 0.4611, 0.3331, 0.335, 0.2193, 0.4822
# current mean recall: 0.3661
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 51/10000
# epoch 51 average loss: 0.8687
# current epoch: 51 current mean recall per class: 0.429, 0.2794, 0.2475, 0.2196, 0.5447
# current mean recall: 0.3440
# best mean recall: 0.3684 at epoch: 41
# ----------
# epoch 52/10000
# epoch 52 average loss: 0.8646
# saved new best metric model
# current epoch: 52 current mean recall per class: 0.316, 0.3027, 0.3736, 0.2433, 0.6288
# current mean recall: 0.3729
# best mean recall: 0.3729 at epoch: 52
# ----------
# epoch 53/10000
# epoch 53 average loss: 0.8628
# saved new best metric model
# current epoch: 53 current mean recall per class: 0.4918, 0.2464, 0.4191, 0.1766, 0.6499
# current mean recall: 0.3968
# best mean recall: 0.3968 at epoch: 53
# ----------
# epoch 54/10000
# epoch 54 average loss: 0.8578
# current epoch: 54 current mean recall per class: 0.3716, 0.2658, 0.3482, 0.249, 0.6241
# current mean recall: 0.3717
# best mean recall: 0.3968 at epoch: 53
# ----------
# epoch 55/10000
# epoch 55 average loss: 0.8481
# current epoch: 55 current mean recall per class: 0.3994, 0.281, 0.2639, 0.1684, 0.5504
# current mean recall: 0.3326
# best mean recall: 0.3968 at epoch: 53
# ----------
# epoch 56/10000
# epoch 56 average loss: 0.8444
# current epoch: 56 current mean recall per class: 0.2818, 0.1956, 0.3019, 0.1691, 0.4836
# current mean recall: 0.2864
# best mean recall: 0.3968 at epoch: 53
# ----------
# epoch 57/10000
# epoch 57 average loss: 0.8514
# current epoch: 57 current mean recall per class: 0.3896, 0.2747, 0.2499, 0.1995, 0.5433
# current mean recall: 0.3314
# best mean recall: 0.3968 at epoch: 53
# ----------
# epoch 58/10000
# epoch 58 average loss: 0.8566
# current epoch: 58 current mean recall per class: 0.4517, 0.2341, 0.366, 0.2246, 0.598
# current mean recall: 0.3749
# best mean recall: 0.3968 at epoch: 53
# ----------
# epoch 59/10000
# epoch 59 average loss: 0.8446
# current epoch: 59 current mean recall per class: 0.2535, 0.2587, 0.3888, 0.2093, 0.5711
# current mean recall: 0.3363
# best mean recall: 0.3968 at epoch: 53
# ----------
# epoch 60/10000
# epoch 60 average loss: 0.8344
# current epoch: 60 current mean recall per class: 0.435, 0.2888, 0.3681, 0.1972, 0.6172
# current mean recall: 0.3813
# best mean recall: 0.3968 at epoch: 53
# ----------
# epoch 61/10000
# epoch 61 average loss: 0.8340
# saved new best metric model
# current epoch: 61 current mean recall per class: 0.4809, 0.2987, 0.4489, 0.2281, 0.6006
# current mean recall: 0.4114
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 62/10000
# epoch 62 average loss: 0.8348
# current epoch: 62 current mean recall per class: 0.4291, 0.2436, 0.3958, 0.2458, 0.5597
# current mean recall: 0.3748
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 63/10000
# epoch 63 average loss: 0.8334
# current epoch: 63 current mean recall per class: 0.423, 0.2818, 0.3668, 0.224, 0.5783
# current mean recall: 0.3748
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 64/10000
# epoch 64 average loss: 0.8384
# current epoch: 64 current mean recall per class: 0.3966, 0.2586, 0.3113, 0.2021, 0.5793
# current mean recall: 0.3496
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 65/10000
# epoch 65 average loss: 0.8383
# current epoch: 65 current mean recall per class: 0.3666, 0.2505, 0.3749, 0.2373, 0.6139
# current mean recall: 0.3686
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 66/10000
# epoch 66 average loss: 0.8373
# current epoch: 66 current mean recall per class: 0.3745, 0.277, 0.4085, 0.2591, 0.6254
# current mean recall: 0.3889
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 67/10000
# epoch 67 average loss: 0.8400
# current epoch: 67 current mean recall per class: 0.4388, 0.2998, 0.3556, 0.2213, 0.6263
# current mean recall: 0.3883
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 68/10000
# epoch 68 average loss: 0.8373
# current epoch: 68 current mean recall per class: 0.2879, 0.1907, 0.2924, 0.2101, 0.6296
# current mean recall: 0.3221
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 69/10000
# epoch 69 average loss: 0.8380
# current epoch: 69 current mean recall per class: 0.3898, 0.2497, 0.3011, 0.1935, 0.5495
# current mean recall: 0.3367
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 70/10000
# epoch 70 average loss: 0.8345
# current epoch: 70 current mean recall per class: 0.4121, 0.2972, 0.3723, 0.2116, 0.4935
# current mean recall: 0.3573
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 71/10000
# epoch 71 average loss: 0.8332
# current epoch: 71 current mean recall per class: 0.4698, 0.2913, 0.33, 0.2423, 0.6344
# current mean recall: 0.3936
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 72/10000
# epoch 72 average loss: 0.8376
# current epoch: 72 current mean recall per class: 0.3713, 0.253, 0.2821, 0.2171, 0.5945
# current mean recall: 0.3436
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 73/10000
# epoch 73 average loss: 0.8194
# current epoch: 73 current mean recall per class: 0.4259, 0.2647, 0.4079, 0.2597, 0.6073
# current mean recall: 0.3931
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 74/10000
# epoch 74 average loss: 0.8443
# current epoch: 74 current mean recall per class: 0.3577, 0.2836, 0.3256, 0.2154, 0.5838
# current mean recall: 0.3532
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 75/10000
# epoch 75 average loss: 0.8277
# current epoch: 75 current mean recall per class: 0.4405, 0.3287, 0.3943, 0.2502, 0.5863
# current mean recall: 0.4000
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 76/10000
# epoch 76 average loss: 0.8394
# current epoch: 76 current mean recall per class: 0.3743, 0.314, 0.3372, 0.2607, 0.6408
# current mean recall: 0.3854
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 77/10000
# epoch 77 average loss: 0.8363
# current epoch: 77 current mean recall per class: 0.4696, 0.272, 0.3283, 0.2105, 0.6453
# current mean recall: 0.3851
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 78/10000
# epoch 78 average loss: 0.8180
# current epoch: 78 current mean recall per class: 0.3754, 0.2719, 0.3975, 0.228, 0.6402
# current mean recall: 0.3826
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 79/10000
# epoch 79 average loss: 0.8084
# current epoch: 79 current mean recall per class: 0.4745, 0.2594, 0.3289, 0.1857, 0.5671
# current mean recall: 0.3631
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 80/10000
# epoch 80 average loss: 0.8321
# current epoch: 80 current mean recall per class: 0.4171, 0.2854, 0.3205, 0.2272, 0.628
# current mean recall: 0.3756
# best mean recall: 0.4114 at epoch: 61
# ----------
# epoch 81/10000
# epoch 81 average loss: 0.8243
# saved new best metric model
# current epoch: 81 current mean recall per class: 0.4418, 0.3206, 0.4465, 0.2428, 0.7066
# current mean recall: 0.4317
# best mean recall: 0.4317 at epoch: 81
# ----------
# epoch 82/10000
# epoch 82 average loss: 0.8078
# current epoch: 82 current mean recall per class: 0.434, 0.2959, 0.4316, 0.2592, 0.6873
# current mean recall: 0.4216
# best mean recall: 0.4317 at epoch: 81
# ----------
# epoch 83/10000
# epoch 83 average loss: 0.8164
# current epoch: 83 current mean recall per class: 0.4349, 0.3987, 0.4257, 0.2967, 0.5692
# current mean recall: 0.4250
# best mean recall: 0.4317 at epoch: 81
# ----------
# epoch 84/10000
# epoch 84 average loss: 0.8273
# current epoch: 84 current mean recall per class: 0.4222, 0.3202, 0.3869, 0.3082, 0.6131
# current mean recall: 0.4101
# best mean recall: 0.4317 at epoch: 81
# ----------
# epoch 85/10000
# epoch 85 average loss: 0.8272
# saved new best metric model
# current epoch: 85 current mean recall per class: 0.4472, 0.3596, 0.387, 0.3099, 0.6556
# current mean recall: 0.4319
# best mean recall: 0.4319 at epoch: 85
# ----------
# epoch 86/10000
# epoch 86 average loss: 0.8152
# current epoch: 86 current mean recall per class: 0.3902, 0.2733, 0.3749, 0.2418, 0.6316
# current mean recall: 0.3824
# best mean recall: 0.4319 at epoch: 85
# ----------
# epoch 87/10000
# epoch 87 average loss: 0.8128
# current epoch: 87 current mean recall per class: 0.4655, 0.3297, 0.3641, 0.2581, 0.6332
# current mean recall: 0.4101
# best mean recall: 0.4319 at epoch: 85
# ----------
# epoch 88/10000
# epoch 88 average loss: 0.8110
# current epoch: 88 current mean recall per class: 0.416, 0.222, 0.4403, 0.2352, 0.5919
# current mean recall: 0.3811
# best mean recall: 0.4319 at epoch: 85
# ----------
# epoch 89/10000
# epoch 89 average loss: 0.8041
# saved new best metric model
# current epoch: 89 current mean recall per class: 0.3805, 0.3758, 0.3801, 0.3205, 0.7076
# current mean recall: 0.4329
# best mean recall: 0.4329 at epoch: 89
# ----------
# epoch 90/10000
# epoch 90 average loss: 0.8202
# current epoch: 90 current mean recall per class: 0.3377, 0.2702, 0.3374, 0.2148, 0.5611
# current mean recall: 0.3442
# best mean recall: 0.4329 at epoch: 89
# ----------
# epoch 91/10000
# epoch 91 average loss: 0.8087
# current epoch: 91 current mean recall per class: 0.505, 0.3296, 0.366, 0.2396, 0.6489
# current mean recall: 0.4178
# best mean recall: 0.4329 at epoch: 89
# ----------
# epoch 92/10000
# epoch 92 average loss: 0.8132
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 23
#      20     f.write(str(summary(model)))
#      21 mlflow.log_artifact("model_summary.txt")
# ---> 23 train(train_loader, model, dice_metric, optimizer, max_epochs=epochs)
#      25 # Save the trained model to MLflow.
#      26 mlflow.pytorch.log_model(model, "model")
#
# Cell In[46], line 49, in train(train_loader, model, metrics_function, optimizer, max_epochs)
#      47 model.eval()
#      48 with torch.no_grad():
# ---> 49     for val_data in val_loader:
#      50         val_inputs = val_data["image"].to(device)
#      51         val_labels = val_data["label"].to(device)
#
# File ~/venvs/ml/lib/python3.12/site-packages/torch/utils/data/dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File ~/venvs/ml/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1448, in _MultiProcessingDataLoaderIter._next_data(self)
#    1445     return self._process_data(data)
#    1447 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1448 idx, data = self._get_data()
#    1449 self._tasks_outstanding -= 1
#    1450 if self._dataset_kind == _DatasetKind.Iterable:
#    1451     # Check for _IterableDatasetStopIteration
#
# File ~/venvs/ml/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1402, in _MultiProcessingDataLoaderIter._get_data(self)
#    1400 elif self._pin_memory:
#    1401     while self._pin_memory_thread.is_alive():
# -> 1402         success, data = self._try_get_data()
#    1403         if success:
#    1404             return data
#
# File ~/venvs/ml/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1243, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1230 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1231     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1232     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1240     # Returns a 2-tuple:
#    1241     #   (bool: whether successfully get data, any: data if successful else None)
#    1242     try:
# -> 1243         data = self._data_queue.get(timeout=timeout)
#    1244         return (True, data)
#    1245     except Exception as e:
#    1246         # At timeout and error, we manually check whether any worker has
#    1247         # failed. Note that this is the only mechanism for Windows to detect
#    1248         # worker failures.
#
# File /usr/local/lib/python3.12/queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File /usr/local/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# **Note:** Code taken from the official CZ Imaging Institute's official github page.
